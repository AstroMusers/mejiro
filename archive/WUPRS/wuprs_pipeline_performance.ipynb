# %%
import os
import sys

path = os.getcwd()
while os.path.basename(os.path.normpath(path)) != 'roman-pandeia':
    path = os.path.dirname(path)
repo_path = path
if repo_path not in sys.path:
    sys.path.append(repo_path)

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['axes.grid'] = False
matplotlib.rcParams['image.origin'] = 'lower'
import numpy as np

from package.plots import diagnostic_plot

# %%
array_dir = os.path.join(repo_path, 'output', 'arrays', 'diagnostics')
figure_dir = os.path.join(repo_path, 'figures', 'diagnostics')

# %%
modeling_pipeline_execution_times = np.load(os.path.join(array_dir, 'modeling_pipeline_execution_times.npy'))
# filepath = os.path.join(figure_dir, 'modeling_pipeline_execution_times.png')

diagnostic_plot.execution_time_hist(None, 'Modeling pipeline execution times', modeling_pipeline_execution_times)

# %%
diagnostic_plot.execution_time_scatter(None, 'Modeling pipeline execution times', modeling_pipeline_execution_times)

# %%
simulation_pipeline_execution_times = np.load(os.path.join(array_dir, 'simulation_pipeline_execution_times.npy'))
# filepath = os.path.join(figure_dir, 'simulation_pipeline_execution_times.png')

diagnostic_plot.execution_time_hist(None, 'Simulation pipeline execution times', simulation_pipeline_execution_times)

# %%
diagnostic_plot.execution_time_scatter(None, 'Simulation pipeline execution times', simulation_pipeline_execution_times)
