# %% [markdown]
# # Roman configurations

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import slsim
from slsim.lens_pop import LensPop
from slsim.Observations.roman_speclite import configure_roman_filters
from slsim.Observations.roman_speclite import filter_names
from slsim.Plots.lens_plots import LensingPlots
import speclite
from astropy.cosmology import FlatLambdaCDM
from astropy.units import Quantity
import corner

# %matplotlib inline

# %%
# Import default Roman Space Telescope configuration
path = os.path.dirname(slsim.__file__)
module_path, _ = os.path.split(path)
skypy_config = os.path.join(module_path, "data/SkyPy/roman-like.yml")

# generate Roman filters
configure_roman_filters()

# import filter bands and make them recogniable in speclite
roman_filters = filter_names()
# filters are ['Roman-F062', 'Roman-F087', 'Roman-F106', 'Roman-F129', 'Roman-F158', 'Roman-F184', 'Roman-F146', 'Roman-F213']

speclite.filters.load_filters(
    roman_filters[0],
    roman_filters[1],
    roman_filters[2],
    roman_filters[3],
    roman_filters[4],
    roman_filters[5],
    roman_filters[6],
    roman_filters[7],
)

# %%
# define a cosmology
cosmo = FlatLambdaCDM(H0=70, Om0=0.3)

# define a sky area
sky_area = Quantity(value=0.5, unit="deg2")


# define limits in the intrinsic deflector and source population (in addition to the skypy config file)
kwargs_deflector_cut = {"band": "F062", "band_max": 25, "z_min": 0.01, "z_max": 3.0}
kwargs_source_cut = {"band": "F062", "band_max": 28, "z_min": 0.01, "z_max": 5.0}


# run skypy pipeline and make galaxy-galaxy population class
lens_pop = LensPop(
    deflector_type="all-galaxies",
    source_type="galaxies",
    kwargs_deflector_cut=kwargs_deflector_cut,
    kwargs_source_cut=kwargs_source_cut,
    kwargs_mass2light=None,
    skypy_config=skypy_config,
    sky_area=sky_area,
    cosmo=cosmo,
)

# %%
kwargs_lens_cut_plot = {
    "min_image_separation": 0.5,
    "max_image_separation": 10,
    "mag_arc_limit": {"F158": 21, "F106": 21, "F062": 21},
}

# make montage of realizations
gg_plot = LensingPlots(lens_pop, num_pix=124, observatory="Roman")


fig, axes = gg_plot.plot_montage(
    rgb_band_list=["F184", "F129", "F062"],
    add_noise=True,
    n_horizont=5,
    n_vertical=2,
    kwargs_lens_cut=kwargs_lens_cut_plot,
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Input In [4], in <cell line: 11>()
#       7 # make montage of realizations
#       8 gg_plot = LensingPlots(lens_pop, num_pix=124, observatory="Roman")
# ---> 11 fig, axes = gg_plot.plot_montage(
#      12     rgb_band_list=["F184", "F129", "F062"],
#      13     add_noise=True,
#      14     n_horizont=5,
#      15     n_vertical=2,
#      16     kwargs_lens_cut=kwargs_lens_cut_plot,
#      17 )
#      18 plt.show()
#
# File /nfshome/bwedig/slsim/slsim/Plots/lens_plots.py:93, in LensingPlots.plot_montage(self, rgb_band_list, add_noise, n_horizont, n_vertical, kwargs_lens_cut)
#      91 for j in range(n_vertical):
#      92     ax = axes[j, i]
# ---> 93     lens_class = self._lens_pop.select_lens_at_random(**kwargs_lens_cut)
#      94     image_rgb = self.rgb_image(
#      95         lens_class, rgb_band_list, add_noise=add_noise
#      96     )
#      97     ax.imshow(image_rgb, aspect="equal", origin="lower")
#
# File /nfshome/bwedig/slsim/slsim/lens_pop.py:204, in LensPop.select_lens_at_random(self, **kwargs_lens_cut)
#     195 lens = self._lens_galaxies.draw_deflector()
#     196 gg_lens = Lens(
#     197     deflector_dict=lens,
#     198     source_dict=source,
#    (...)
#     202     source_type=self._source_model_type,
#     203 )
# --> 204 if gg_lens.validity_test(**kwargs_lens_cut):
#     205     return gg_lens
#
# File /nfshome/bwedig/slsim/slsim/lens.py:217, in Lens.validity_test(self, min_image_separation, max_image_separation, mag_arc_limit)
#     214     return False
#     216 # Criteria 4: The lensing configuration must produce at least two SL images.
# --> 217 image_positions = self.point_source_image_positions()
#     218 if len(image_positions[0]) < 2:
#     219     return False
#
# File /nfshome/bwedig/slsim/slsim/lens.py:166, in Lens.point_source_image_positions(self)
#     164     else:
#     165         solver = "lenstronomy"
# --> 166     self._point_image_positions = lens_eq_solver.image_position_from_source(
#     167         point_source_pos_x,
#     168         point_source_pos_y,
#     169         kwargs_lens,
#     170         solver=solver,
#     171         search_window=self.einstein_radius * 6,
#     172         min_distance=self.einstein_radius * 6 / 200,
#     173         magnification_limit=self._magnification_limit,
#     174     )
#     175 return self._point_image_positions
#
# File /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/lens_equation_solver.py:245, in LensEquationSolver.image_position_from_source(self, sourcePos_x, sourcePos_y, kwargs_lens, solver, **kwargs)
#     241     return self.image_position_lenstronomy(
#     242         sourcePos_x, sourcePos_y, kwargs_lens, **kwargs
#     243     )
#     244 if solver == "analytical":
# --> 245     return self.image_position_analytical(
#     246         sourcePos_x, sourcePos_y, kwargs_lens, **kwargs
#     247     )
#     248 if solver == "stochastic":
#     249     return self.image_position_stochastic(
#     250         sourcePos_x, sourcePos_y, kwargs_lens, **kwargs
#     251     )
#
# File /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/lens_equation_solver.py:213, in LensEquationSolver.image_position_analytical(self, x, y, kwargs_lens, arrival_time_sort, magnification_limit, **kwargs_solver)
#     209 if lens_model_list not in SUPPORTED_LENS_MODELS_ANALYTICAL:
#     210     raise ValueError(
#     211         "Only SIE, EPL, EPL_NUMBA (+shear +convergence) supported in the analytical solver for now."
#     212     )
# --> 213 x_mins, y_mins = solve_lenseq_pemd((x_, y_), kwargs_lens_, **kwargs_solver)
#     215 if arrival_time_sort:
#     216     x_mins, y_mins = self.sort_arrival_times(x_mins, y_mins, kwargs_lens)
#
# File /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/epl_shear_solver.py:299, in solve_lenseq_pemd(pos_, kwargs_lens, Nmeas, Nmeas_extra, **kwargs)
#     297 gamma *= rotfact**2
#     298 p *= rotfact
# --> 299 res = solvelenseq_majoraxis(
#     300     (b, t, p.real, p.imag, q, gamma.real, gamma.imag),
#     301     Nmeas=Nmeas,
#     302     Nmeas_extra=Nmeas_extra,
#     303 )
#     304 xsol, ysol = res
#     305 x = np.array([(xs + 1j * ys) / rotfact + cen for xs, ys in zip(xsol, ysol)])
#
# File /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/epl_shear_solver.py:246, in solvelenseq_majoraxis(args, Nmeas, Nmeas_extra)
#     239 Rs = np.array([_getr(theta, (b, t, y1, y2, q, gamma1, gamma2)) for theta in thetas])
#     240 stuff = np.array(pol_to_cart(Rs[Rs > 0], thetas[Rs > 0]))
#     241 diff = (
#     242     -y1
#     243     - y2 * 1j
#     244     + stuff[0]
#     245     + stuff[1] * 1j
# --> 246     - _alpha_epl_shear(stuff[0], stuff[1], b, q, t, gamma1=gamma1, gamma2=gamma2)
#     247 )
#     248 goodones = np.abs(diff) < 1e-8
#     249 return findOverlap(*stuff[:, goodones], 1e-8)
#
# File /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/numba/core/dispatcher.py:468, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     464         msg = (f"{str(e).rstrip()} \n\nThis error may have been caused "
#     465                f"by the following argument(s):\n{args_str}\n")
#     466         e.patch_message(msg)
# --> 468     error_rewrite(e, 'typing')
#     469 except errors.UnsupportedError as e:
#     470     # Something unsupported is present in the user code, add help info
#     471     error_rewrite(e, 'unsupported_error')
#
# File /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/numba/core/dispatcher.py:409, in _DispatcherBase._compile_for_args.<locals>.error_rewrite(e, issue_type)
#     407     raise e
#     408 else:
# --> 409     raise e.with_traceback(None)
#
# TypingError: Failed in nopython mode pipeline (step: nopython frontend)
# Failed in nopython mode pipeline (step: nopython frontend)
# Use of unsupported NumPy function 'numpy.nan_to_num' or unsupported use of the function.
#
# File "../../../data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Profiles/epl_numba.py", line 190:
# def alpha(x, y, b, q, t, Omega=None):
#     <source elided>
#     # TODO: check whether numba is active with np.nan_to_num instead of numba_util.nan_to_num
#     alph = (2 * b) / (1 + q) * np.nan_to_num((b / R) ** t * R / b) * Omega
#     ^
#
# During: typing of get attribute at /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Profiles/epl_numba.py (190)
#
# File "../../../data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Profiles/epl_numba.py", line 190:
# def alpha(x, y, b, q, t, Omega=None):
#     <source elided>
#     # TODO: check whether numba is active with np.nan_to_num instead of numba_util.nan_to_num
#     alph = (2 * b) / (1 + q) * np.nan_to_num((b / R) ** t * R / b) * Omega
#     ^
#
# During: resolving callee type: type(CPUDispatcher(<function alpha at 0x7fe598af03a0>))
# During: typing of call at /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/epl_shear_solver.py (30)
#
# During: resolving callee type: type(CPUDispatcher(<function alpha at 0x7fe598af03a0>))
# During: typing of call at /data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/epl_shear_solver.py (30)
#
#
# File "../../../data/bwedig/.conda/envs/mejiro/lib/python3.10/site-packages/lenstronomy/LensModel/Solver/epl_shear_solver.py", line 30:
# def _alpha_epl_shear(x, y, b, q, t=1, gamma1=0, gamma2=0, Omega=None):
#     <source elided>
#     return (
#         alpha(x, y, b, q, t=t, Omega=Omega)
#         ^

# %%
kwargs_lens_cut = {
    "min_image_separation": 0.1,
    "max_image_separation": 10,
    "mag_arc_limit": {"F158": 25, "F106": 25, "F062": 25},
}


lens_population = lens_pop.draw_population(kwargs_lens_cuts=kwargs_lens_cut)

# %%
print("Number of lenses:", len(lens_population))

lens_samples = []
labels = [
    r"$\sigma_v$",
    r"$\log(M_{*})$",
    r"$\theta_E$",
    r"$z_{\rm l}$",
    r"$z_{\rm s}$",
    r"$m_{\rm source}$",
    r"$m_{\rm lens}$",
]

for gg_lens in lens_population:
    vel_disp = gg_lens.deflector_velocity_dispersion()
    m_star = gg_lens.deflector_stellar_mass()
    theta_e = gg_lens.einstein_radius
    zl = gg_lens.deflector_redshift
    zs = gg_lens.source_redshift
    source_mag = gg_lens.extended_source_magnitude(band="F184", lensed=True)
    deflector_mag = gg_lens.deflector_magnitude(band="F184")
    lens_samples.append(
        [vel_disp, np.log10(m_star), theta_e, zl, zs, source_mag, deflector_mag]
    )
# Out:
# Number of lenses: 3840

# %%
hist2dkwargs = {
    "plot_density": False,
    "plot_contours": False,
    "plot_datapoints": True,
    "color": "b",
    "data_kwargs": {"ms": 5},
}
corner.corner(np.array(lens_samples), labels=labels, **hist2dkwargs)
plt.show()
