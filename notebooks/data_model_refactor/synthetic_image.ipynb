# %%
import os
import sys

import numpy as np
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import colors
from hydra import initialize, compose
import pickle
from glob import glob
from pprint import pprint
from tqdm import tqdm

# set paths to various directories based on the machine this code is being executed on
try:
    with initialize(version_base=None, config_path='config'):  
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']
except:
    with initialize(version_base=None, config_path='../../config'):  
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']

array_dir, data_dir, figure_dir, pickle_dir, repo_dir  = config.machine.array_dir, config.machine.data_dir, config.machine.figure_dir, config.machine.pickle_dir, config.machine.repo_dir

# enable use of local modules
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# set matplotlib style
plt.style.use(f'{repo_dir}/mejiro/mplstyle/science.mplstyle')

from mejiro.utils import util
from mejiro.instruments.roman import Roman
from mejiro.synthetic_image import SyntheticImage
from mejiro.lenses.test import SampleStrongLens

# %%
roman = Roman()
lens = SampleStrongLens()

# %%
synth = SyntheticImage(lens, roman, 'F129', arcsec=5., oversample=5)
# Out:
# Computing on pixel grid of size 235x235 (5.17"x5.17") with pixel scale 0.022 arcsec/pixel (natively 0.11 arcsec/pixel oversampled by factor 5)
# Computing with kwargs_numerics: {'supersampling_factor': 3, 'compute_mode': 'adaptive', 'supersampled_indexes': array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 synth = SyntheticImage(lens, roman, 'F129', arcsec=5., oversample=5)
#
# File /nfshome/bwedig/mejiro/mejiro/synthetic_image.py:39, in SyntheticImage.__init__(self, strong_lens, instrument, band, arcsec, oversample, kwargs_numerics, pieces, verbose, instrument_params)
#      35     kwargs_numerics['supersampled_indexes'] = self.supersampled_indexes
#      37 if self.verbose: print(f'Computing with kwargs_numerics: {kwargs_numerics}')
# ---> 39 self._calculate_surface_brightness(kwargs_numerics, pieces)
#      41 if self.verbose: print(
#      42     f'Initialized SyntheticImage for StrongLens {self.strong_lens.uid} by {self.instrument.name} in {self.band} band')
#
# File /nfshome/bwedig/mejiro/mejiro/synthetic_image.py:146, in SyntheticImage._calculate_surface_brightness(self, kwargs_numerics, pieces, kwargs_psf)
#     143 # to create ImageModel, need LensModel and LightModel objects
#     144 self.strong_lens._set_classes()
# --> 146 image_model = ImageModel(data_class=self.pixel_grid,
#     147                          psf_class=psf_class,  # TODO does this need to be passed in? I never want to convolve with a PSF at this stage
#     148                          lens_model_class=self.strong_lens.lens_model_class,
#     149                          source_model_class=self.strong_lens.source_model_class,
#     150                          lens_light_model_class=self.strong_lens.lens_light_model_class,
#     151                          kwargs_numerics=kwargs_numerics)
#     153 self._convert_magnitudes_to_lenstronomy_amps()
#     154 kwargs_lens_light_amp = [self.strong_lens.kwargs_lens_light_amp_dict[self.band]]
#
# File /nfshome/bwedig/lenstronomy/lenstronomy/ImSim/image_model.py:55, in ImageModel.__init__(self, data_class, psf_class, lens_model_class, source_model_class, lens_light_model_class, point_source_class, extinction_class, kwargs_numerics, kwargs_pixelbased)
#      53 if kwargs_numerics is None:
#      54     kwargs_numerics = {}
# ---> 55 self.ImageNumerics = NumericsSubFrame(
#      56     pixel_grid=self.Data, psf=self.PSF, **kwargs_numerics
#      57 )
#      58 if lens_model_class is None:
#      59     lens_model_class = LensModel(lens_model_list=[])
#
# File /nfshome/bwedig/lenstronomy/lenstronomy/ImSim/Numerics/numerics_subframe.py:59, in NumericsSubFrame.__init__(self, pixel_grid, psf, supersampling_factor, compute_mode, supersampling_convolution, supersampling_kernel_size, flux_evaluate_indexes, supersampled_indexes, compute_indexes, point_source_supersampling_factor, convolution_kernel_size, convolution_type, truncation)
#      57 self._init_sub_frame(flux_evaluate_indexes)
#      58 pixel_grid_sub = self._sub_pixel_grid(pixel_grid)
# ---> 59 self._numerics_subframe = Numerics(
#      60     pixel_grid=pixel_grid_sub,
#      61     psf=psf,
#      62     supersampling_factor=supersampling_factor,
#      63     compute_mode=compute_mode,
#      64     supersampling_convolution=supersampling_convolution,
#      65     supersampling_kernel_size=supersampling_kernel_size,
#      66     flux_evaluate_indexes=self._cut_frame(flux_evaluate_indexes),
#      67     supersampled_indexes=self._cut_frame(supersampled_indexes),
#      68     compute_indexes=self._cut_frame(compute_indexes),
#      69     point_source_supersampling_factor=point_source_supersampling_factor,
#      70     convolution_kernel_size=convolution_kernel_size,
#      71     convolution_type=convolution_type,
#      72     truncation=truncation,
#      73 )
#      74 super(NumericsSubFrame, self).__init__(
#      75     pixel_grid=pixel_grid,
#      76     supersampling_factor=point_source_supersampling_factor,
#      77     psf=psf,
#      78 )
#
# File /nfshome/bwedig/lenstronomy/lenstronomy/ImSim/Numerics/numerics.py:83, in Numerics.__init__(self, pixel_grid, psf, supersampling_factor, compute_mode, supersampling_convolution, supersampling_kernel_size, flux_evaluate_indexes, supersampled_indexes, compute_indexes, point_source_supersampling_factor, convolution_kernel_size, convolution_type, truncation)
#      79     supersampled_indexes = np.zeros((nx, ny), dtype=bool)
#      80 if (
#      81     compute_mode == "adaptive"
#      82 ):  # or (compute_mode == 'regular' and supersampling_convolution is False and supersampling_factor > 1):
# ---> 83     self._grid = AdaptiveGrid(
#      84         nx,
#      85         ny,
#      86         transform_pix2angle,
#      87         ra_at_xy_0,
#      88         dec_at_xy_0,
#      89         supersampled_indexes,
#      90         supersampling_factor,
#      91         flux_evaluate_indexes,
#      92     )
#      93 else:
#      94     self._grid = RegularGrid(
#      95         nx,
#      96         ny,
#    (...)
#     101         flux_evaluate_indexes,
#     102     )
#
# File /nfshome/bwedig/lenstronomy/lenstronomy/ImSim/Numerics/grid.py:45, in AdaptiveGrid.__init__(self, nx, ny, transform_pix2angle, ra_at_xy_0, dec_at_xy_0, supersampling_indexes, supersampling_factor, flux_evaluate_indexes)
#      43     flux_evaluate_indexes = np.ones_like(self._x_grid, dtype=bool)
#      44 supersampled_indexes1d = util.image2array(supersampling_indexes)
# ---> 45 self._high_res_indexes1d = (supersampled_indexes1d) & (flux_evaluate_indexes)
#      46 self._low_res_indexes1d = (np.invert(supersampled_indexes1d)) & (
#      47     flux_evaluate_indexes
#      48 )
#      49 self._supersampling_factor = supersampling_factor
#
# ValueError: operands could not be broadcast together with shapes (2209,) (55225,)

# %%
plt.imshow(np.log10(synth.image))
plt.colorbar()
plt.title(f'Sum={np.sum(synth.image):.2f}')
plt.show()

# %%
plt.matshow(synth.supersampled_indexes)
