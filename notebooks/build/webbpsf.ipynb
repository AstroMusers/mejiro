# %%
import webbpsf
from webbpsf import roman
import matplotlib.pyplot as plt

# %%
wfi = roman.WFI()
wfi.filter = 'F106'
psf = wfi.calc_psf(oversample=5)
plt.imshow(psf[0].data)

# %%
print(psf[0].data.shape)
# Out:
# (225, 225)

# %%
webbpsf.display_psf(psf)

# %%
wfi.calc_psf(f'webbpsf_{wfi.filter.lower()}.fits')
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x29219da60>, <astropy.io.fits.hdu.image.ImageHDU object at 0x17fee32f0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x2e8b02720>, <astropy.io.fits.hdu.image.ImageHDU object at 0x17fe01130>]
