# %%
import webbpsf
from webbpsf import roman
import matplotlib.pyplot as plt

# %%
wfi = roman.WFI()
wfi.filter = 'F106'
psf = wfi.calc_psf(oversample=4)
plt.imshow(psf[0].data)

# %%
webbpsf.display_psf(psf)

# %%
wfi.calc_psf(f'webbpsf_{wfi.filter.lower()}.fits')
# Out:
# WARNING: VerifyWarning: Card is too long, comment will be truncated. [astropy.io.fits.card]
# [<astropy.io.fits.hdu.image.PrimaryHDU object at 0x17fe36690>, <astropy.io.fits.hdu.image.ImageHDU object at 0x17fdcdeb0>, <astropy.io.fits.hdu.image.ImageHDU object at 0x29219dd00>, <astropy.io.fits.hdu.image.ImageHDU object at 0x17fda8e60>]
