# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.rcParams['axes.grid'] = False
matplotlib.rcParams['image.origin'] = 'lower'
import numpy as np

# %%
modeling_pipeline_execution_times = np.load('modeling_pipeline_execution_times.npy')

plt.scatter(np.arange(0, len(modeling_pipeline_execution_times)), modeling_pipeline_execution_times)
plt.title('Modeling pipeline execution times')
plt.savefig('modeling_pipeline_execution_times.png')
plt.show()

# %%
simulation_pipeline_execution_times = np.load('simulation_pipeline_execution_times.npy')

plt.scatter(np.arange(0, len(simulation_pipeline_execution_times)), simulation_pipeline_execution_times)
plt.title('Simulation pipeline execution times')
plt.savefig('simulation_pipeline_execution_times.png')
plt.show()
