# %%
import os
import sys

import random
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from hydra import initialize, compose
from glob import glob
from pprint import pprint

# set paths to various directories based on the machine this code is being executed on
try:
    with initialize(version_base=None, config_path='config'):  
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']
except:
    with initialize(version_base=None, config_path='../../config'):  
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']

array_dir, data_dir, figure_dir, pickle_dir, repo_dir  = config.machine.array_dir, config.machine.data_dir, config.machine.figure_dir, config.machine.pickle_dir, config.machine.repo_dir

# enable use of local modules
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# set matplotlib style
plt.style.use(f'{repo_dir}/mejiro/mplstyle/science.mplstyle')

from mejiro.plots import plot
from mejiro.utils import util

# %%
pipeline_params = util.hydra_to_dict(config.pipeline)
debugging = pipeline_params['debugging']
if debugging:
    pipeline_dir = f'{config.machine.pipeline_dir}_dev'
else:
    pipeline_dir = config.machine.pipeline_dir

output_dir = os.path.join(data_dir, 'fits_export')
all_fits_files = glob(f'{output_dir}/*.fits')
print(f'{len(all_fits_files)} fits files found in {output_dir}')
# Out:
# 10 fits files found in /data/bwedig/mejiro/fits_export

# %%
fits_path = random.choice(all_fits_files)
print(f'Randomly selected fits file: {fits_path}')
# Out:
# Randomly selected fits file: /data/bwedig/mejiro/fits_export/roman_hlwas_strong_lens_00010441.fits

# %%
fits.info(fits_path)
# Out:
# Filename: /data/bwedig/mejiro/fits_export/roman_hlwas_strong_lens_00010441.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   ()
#   1  F087          1 ImageHDU        20   (91, 91)   float32
#   2  F106          1 ImageHDU        20   (91, 91)   float32
#   3  F129          1 ImageHDU        20   (91, 91)   float32
#   4  F158          1 ImageHDU        20   (91, 91)   float32
#   5  F184          1 ImageHDU        20   (91, 91)   float32

# %%
for i in range(4):
    pprint(fits.getheader(fits_path, ext=i))
    print('\n')
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# VERSION = '0.1     '           / mejiro version
# AUTHOR  = 'bwedig@parsley.physics.wustl.edu' / username@host for calculation
# CREATED = '2024_11_03-01_29_06_PM'
# UID     = '00010441'           / UID for system assigned by mejiro
# ZSOURCE =   1.0888410963957675 / Source galaxy redshift
# ZLENS   =   0.4177699555485822 / Lens galaxy redshift
# DS      =    3.610789267218137 / Comoving distance to source galaxy [Gpc]
# DL      =   1.6631865874978713 / Comoving distance to lens galaxy [Gpc]
# DLS     =   1.9476026797202657 / Comoving distance between lens and source [Gpc]
# HALOMASS=   1646203726124.7773 / Lens galaxy main halo mass [M_sun]
# THETAE  =   0.6883502424646433 / Einstein radius [arcsec]
# SIGMAV  =   210.35790112132725 / Lens galaxy velocity dispersion [km/s]
# MU      =    6.167326337222111 / Flux-weighted magnification of source
# NUMIMAGE=                    4 / Number of images formed by the system
# SNR     =   30.757610865075478 / Signal-to-noise ratio in F129 band
# LOGMLOW =                    6 / Lower mass limit for subhalos [log10(M_sun)]
# LOGMHIGH=                   10 / Upper mass limit for subhalos [log10(M_sun)]
# RTIDAL  =                  0.5 / See pyHalo documentation
# SIGMASUB=                0.055 / See pyHalo documentation
# NUMSUB  =                  174 / Number of subhalos
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F087    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=  / Detector
# DET_X   =                 2048 / Detector X position
# DET_Y   =                 2048 / Detector Y position
# SOURCMAG=   24.441946520533424 / Unlensed source galaxy AB magnitude
# MAGNMAG =   22.466704197422466 / Lensed source galaxy AB magnitude
# LENSMAG =   20.596686125217865 / Lens galaxy AB magnitude
# EXTNAME = 'F087    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F106    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=  / Detector
# DET_X   =                 2048 / Detector X position
# DET_Y   =                 2048 / Detector Y position
# SOURCMAG=   24.165964924128897 / Unlensed source galaxy AB magnitude
# MAGNMAG =    22.19072260101794 / Lensed source galaxy AB magnitude
# LENSMAG =   20.375669090388982 / Lens galaxy AB magnitude
# EXTNAME = 'F106    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F129    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=  / Detector
# DET_X   =                 2048 / Detector X position
# DET_Y   =                 2048 / Detector Y position
# SOURCMAG=   23.966981947697118 / Unlensed source galaxy AB magnitude
# MAGNMAG =    21.99173962458616 / Lensed source galaxy AB magnitude
# LENSMAG =   20.176297958141298 / Lens galaxy AB magnitude
# EXTNAME = 'F129    '           / extension name

# %%
data = []

for i in range(1, 5):
    data.append(fits.getdata(fits_path, ext=i))

fig, axs = plt.subplots(2, 2, figsize=(12, 12))
for i, ax in enumerate(axs.flat):
    ax.imshow(data[i])
    ax.set_title(f'Extension {i + 1}')
plt.tight_layout()
plt.show()
