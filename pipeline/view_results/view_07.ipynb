# %%
import os
import sys

import random
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
from hydra import initialize, compose
from glob import glob
from pprint import pprint

# set paths to various directories based on the machine this code is being executed on
try:
    with initialize(version_base=None, config_path='config'):  
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']
except:
    with initialize(version_base=None, config_path='../../config'):  
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']

array_dir, data_dir, figure_dir, pickle_dir, repo_dir  = config.machine.array_dir, config.machine.data_dir, config.machine.figure_dir, config.machine.pickle_dir, config.machine.repo_dir

# enable use of local modules
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# set matplotlib style
plt.style.use(f'{repo_dir}/mejiro/mplstyle/science.mplstyle')

from mejiro.plots import plot
from mejiro.utils import util

# %%
pipeline_params = util.hydra_to_dict(config.pipeline)
debugging = pipeline_params['debugging']
if debugging:
    pipeline_dir = f'{config.machine.pipeline_dir}_dev'
else:
    pipeline_dir = config.machine.pipeline_dir

output_dir = os.path.join(data_dir, 'fits_export')
all_fits_files = glob(f'{output_dir}/*.fits')
print(f'{len(all_fits_files)} fits files found in {output_dir}')
# Out:
# 14706 fits files found in /data/bwedig/mejiro/fits_export

# %%
fits_path = random.choice(all_fits_files)
print(f'Randomly selected fits file: {fits_path}')
# Out:
# Randomly selected fits file: /data/bwedig/mejiro/fits_export/roman_hlwas_strong_lens_00001534.fits

# %%
fits.info(fits_path)
# Out:
# Filename: /data/bwedig/mejiro/fits_export/roman_hlwas_strong_lens_00001534.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   ()
#   1  F087          1 ImageHDU        20   (91, 91)   float32
#   2  F106          1 ImageHDU        20   (91, 91)   float32
#   3  F129          1 ImageHDU        20   (91, 91)   float32
#   4  F158          1 ImageHDU        20   (91, 91)   float32
#   5  F184          1 ImageHDU        20   (91, 91)   float32

# %%
for i in range(6):
    pprint(fits.getheader(fits_path, ext=i))
    print('\n')
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# VERSION = '0.1     '           / mejiro version
# AUTHOR  = 'bwedig@europa.physics.wustl.edu' / username@host for calculation
# CREATED = '2024_11_03-07_53_53_PM'
# UID     = '00001534'           / UID for system assigned by mejiro
# ZSOURCE =   0.9554878511776986 / Source galaxy redshift
# ZLENS   =   0.5983780007405715 / Lens galaxy redshift
# DS      =   3.2835493335815524 / Comoving distance to source galaxy [Gpc]
# DL      =    2.267294906281353 / Comoving distance to lens galaxy [Gpc]
# DLS     =   1.0162544273001992 / Comoving distance between lens and source [Gpc]
# HALOMASS=    2530847577624.304 / Lens galaxy main halo mass [M_sun]
# THETAE  =   0.4261295781349221 / Einstein radius [arcsec]
# SIGMAV  =   218.49655401058652 / Lens galaxy velocity dispersion [km/s]
# MU      =    4.923666360688227 / Flux-weighted magnification of source
# NUMIMAGE=                    2 / Number of images formed by the system
# SNR     =   53.019131234117125 / Signal-to-noise ratio in F129 band
# LOGMLOW =                    6 / Lower mass limit for subhalos [log10(M_sun)]
# LOGMHIGH=                   10 / Upper mass limit for subhalos [log10(M_sun)]
# RTIDAL  =                  0.5 / See pyHalo documentation
# SIGMASUB=                0.055 / See pyHalo documentation
# NUMSUB  =                  129 / Number of subhalos
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F087    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                    2 / Detector
# DET_X   =                  409 / Detector X position
# DET_Y   =                 3679 / Detector Y position
# SOURCMAG=     23.7983197721773 / Unlensed source galaxy AB magnitude
# MAGNMAG =    22.06759823109716 / Lensed source galaxy AB magnitude
# LENSMAG =   20.636209422565805 / Lens galaxy AB magnitude
# EXTNAME = 'F087    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F106    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                    2 / Detector
# DET_X   =                  409 / Detector X position
# DET_Y   =                 3679 / Detector Y position
# SOURCMAG=    23.54347872007689 / Unlensed source galaxy AB magnitude
# MAGNMAG =    21.81275717899675 / Lensed source galaxy AB magnitude
# LENSMAG =   20.423426081647825 / Lens galaxy AB magnitude
# EXTNAME = 'F106    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F129    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                    2 / Detector
# DET_X   =                  409 / Detector X position
# DET_Y   =                 3679 / Detector Y position
# SOURCMAG=   23.289737722788587 / Unlensed source galaxy AB magnitude
# MAGNMAG =   21.559016181708447 / Lensed source galaxy AB magnitude
# LENSMAG =   20.278168926817628 / Lens galaxy AB magnitude
# EXTNAME = 'F129    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F158    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                    2 / Detector
# DET_X   =                  409 / Detector X position
# DET_Y   =                 3679 / Detector Y position
# SOURCMAG=   23.127417724489092 / Unlensed source galaxy AB magnitude
# MAGNMAG =   21.396696183408952 / Lensed source galaxy AB magnitude
# LENSMAG =   20.110542208545866 / Lens galaxy AB magnitude
# EXTNAME = 'F158    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F184    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                    2 / Detector
# DET_X   =                  409 / Detector X position
# DET_Y   =                 3679 / Detector Y position
# SOURCMAG=    22.95647969173792 / Unlensed source galaxy AB magnitude
# MAGNMAG =    21.22575815065778 / Lensed source galaxy AB magnitude
# LENSMAG =   20.031589166920966 / Lens galaxy AB magnitude
# EXTNAME = 'F184    '           / extension name

# %%
data = []

for i in range(1, 6):
    data.append(fits.getdata(fits_path, ext=i))

fig, axs = plt.subplots(2, 3, figsize=(6, 4), constrained_layout=True)
for i, ax in enumerate(axs.flat):
    if i == 5:
        ax.axis('off')
        continue
    ax.imshow(data[i])
    ax.set_title(f'Extension {i + 1}')
plt.show()
