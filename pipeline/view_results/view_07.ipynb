# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import random
import sys
from astropy.io import fits
from glob import glob
from hydra import initialize, compose
from pprint import pprint

# set paths to various directories based on the machine this code is being executed on
try:
    with initialize(version_base=None, config_path='config'):
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']
except:
    with initialize(version_base=None, config_path='../../config'):
        config = compose(config_name='config.yaml')  # overrides=['machine=uzay']

array_dir, data_dir, figure_dir, pickle_dir, repo_dir = config.machine.array_dir, config.machine.data_dir, config.machine.figure_dir, config.machine.pickle_dir, config.machine.repo_dir

# enable use of local modules
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# set matplotlib style
plt.style.use(f'{repo_dir}/mejiro/mplstyle/science.mplstyle')

from mejiro.plots import plot
from mejiro.utils import util

# %%
pipeline_params = util.hydra_to_dict(config.pipeline)
debugging = pipeline_params['debugging']
if debugging:
    pipeline_dir = f'{config.machine.pipeline_dir}_dev'
else:
    pipeline_dir = config.machine.pipeline_dir

output_dir = os.path.join(data_dir, 'fits_export')
all_fits_files = glob(f'{output_dir}/*.fits')
print(f'{len(all_fits_files)} fits files found in {output_dir}')
# Out:
# 14706 fits files found in /data/bwedig/mejiro/fits_export

# %%
fits_path = random.choice(all_fits_files)
print(f'Randomly selected fits file: {fits_path}')
# Out:
# Randomly selected fits file: /data/bwedig/mejiro/fits_export/roman_hlwas_strong_lens_00008608.fits

# %%
fits.info(fits_path)
# Out:
# Filename: /data/bwedig/mejiro/fits_export/roman_hlwas_strong_lens_00008608.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      24   ()
#   1  F087          1 ImageHDU        20   (91, 91)   float32
#   2  F106          1 ImageHDU        20   (91, 91)   float32
#   3  F129          1 ImageHDU        20   (91, 91)   float32
#   4  F158          1 ImageHDU        20   (91, 91)   float32
#   5  F184          1 ImageHDU        20   (91, 91)   float32

# %%
for i in range(6):
    pprint(fits.getheader(fits_path, ext=i))
    print('\n')
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# VERSION = '0.0.1   '           / mejiro version
# AUTHOR  = 'bwedig@tiberius.physics.wustl.edu' / username@host for calculation
# CREATED = '2024_11_11-05_59_22_PM'
# UID     = '00008608'           / UID for system assigned by mejiro
# ZSOURCE =   0.7698774387111089 / Source galaxy redshift
# ZLENS   =   0.2155926094355461 / Lens galaxy redshift
# DS      =   2.7827488847602977 / Comoving distance to source galaxy [Gpc]
# DL      =   0.9056942109026235 / Comoving distance to lens galaxy [Gpc]
# DLS     =   1.8770546738576743 / Comoving distance between lens and source [Gpc]
# HALOMASS=   4617285107616.3545 / Lens galaxy main halo mass [M_sun]
# THETAE  =   0.9585683762525303 / Einstein radius [arcsec]
# SIGMAV  =    221.9797205308488 / Lens galaxy velocity dispersion [km/s]
# MU      =   7.7270315244875185 / Flux-weighted magnification of source
# NUMIMAGE=                    2 / Number of images formed by the system
# SNR     =    61.61763775916379 / Signal-to-noise ratio in F129 band
# LOGMLOW =                    6 / Lower mass limit for subhalos [log10(M_sun)]
# LOGMHIGH=                   10 / Upper mass limit for subhalos [log10(M_sun)]
# RTIDAL  =                  0.5 / See pyHalo documentation
# SIGMASUB=                0.055 / See pyHalo documentation
# NUMSUB  =                  185 / Number of subhalos
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F087    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                   11 / Detector
# DET_X   =                 1226 / Detector X position
# DET_Y   =                 2044 / Detector Y position
# SOURCMAG=     23.5270941918712 / Unlensed source galaxy AB magnitude
# MAGNMAG =   21.307062481698953 / Lensed source galaxy AB magnitude
# LENSMAG =   18.840804384906704 / Lens galaxy AB magnitude
# EXTNAME = 'F087    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F106    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                   11 / Detector
# DET_X   =                 1226 / Detector X position
# DET_Y   =                 2044 / Detector Y position
# SOURCMAG=   23.199585613252964 / Unlensed source galaxy AB magnitude
# MAGNMAG =   20.979553903080717 / Lensed source galaxy AB magnitude
# LENSMAG =    18.53825194521744 / Lens galaxy AB magnitude
# EXTNAME = 'F106    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F129    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                   11 / Detector
# DET_X   =                 1226 / Detector X position
# DET_Y   =                 2044 / Detector Y position
# SOURCMAG=   22.990126588618693 / Unlensed source galaxy AB magnitude
# MAGNMAG =   20.770094878446447 / Lensed source galaxy AB magnitude
# LENSMAG =   18.271905180917052 / Lens galaxy AB magnitude
# EXTNAME = 'F129    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F158    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                   11 / Detector
# DET_X   =                 1226 / Detector X position
# DET_Y   =                 2044 / Detector Y position
# SOURCMAG=   22.794856270680725 / Unlensed source galaxy AB magnitude
# MAGNMAG =    20.57482456050848 / Lensed source galaxy AB magnitude
# LENSMAG =   18.148357596893668 / Lens galaxy AB magnitude
# EXTNAME = 'F158    '           / extension name
#
#
# XTENSION= 'IMAGE   '           / Image extension
# BITPIX  =                  -32 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                   91
# NAXIS2  =                   91
# PCOUNT  =                    0 / number of parameters
# GCOUNT  =                    1 / number of groups
# INSTRUME= 'WFI     '           / Instrument
# FILTER  = 'F184    '           / Filter
# EXPOSURE=                  146 / Exposure time [seconds]
# OVERSAMP=                    5 / Oversampling used in calculation
# PIXELSCL=                 0.11 / Pixel scale [arcsec/pixel]
# FOV     =                10.01 / Field of view [arcsec]
# DETECTOR=                   11 / Detector
# DET_X   =                 1226 / Detector X position
# DET_Y   =                 2044 / Detector Y position
# SOURCMAG=   22.612925199280994 / Unlensed source galaxy AB magnitude
# MAGNMAG =   20.392893489108747 / Lensed source galaxy AB magnitude
# LENSMAG =   18.031760149057142 / Lens galaxy AB magnitude
# EXTNAME = 'F184    '           / extension name

# %%
data = []

for i in range(1, 6):
    data.append(fits.getdata(fits_path, ext=i))

fig, axs = plt.subplots(2, 3, figsize=(6, 4), constrained_layout=True)
for i, ax in enumerate(axs.flat):
    if i == 5:
        ax.axis('off')
        continue
    ax.imshow(data[i])
    ax.set_title(f'Extension {i + 1}')
plt.show()
