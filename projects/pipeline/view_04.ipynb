# %%
import os
import yaml
from glob import glob

import matplotlib.pyplot as plt
import numpy as np

from mejiro.utils import util

# read configuration file
with open('hwo.yaml', 'r') as f:
    config = yaml.load(f, Loader=yaml.SafeLoader)

# %%
if config['dev']:
    config['pipeline_dir'] += '_dev'

# %%
data_dir = os.path.join(config['data_dir'], config['pipeline_label'], '04')

pickles = sorted(glob(os.path.join(data_dir, 'SyntheticImage_*.pkl')))  # 'sca*', 
print(f'Found {len(pickles)} pickle(s) in {data_dir}')
# Out:
# Found 2816 pickle(s) in /data/bwedig/mejiro/hwo/04

# %%
sample = util.unpickle(pickles[0])
sample.plot()

# %%
_, ax = plt.subplots(10, 10, figsize=(20, 20))

for i in range(100):
    sample = util.unpickle(pickles[i])
    ax.flat[i].imshow(np.log10(sample.image))
    ax.flat[i].axis('off')

plt.show()
# Out:
# /tmp/ipykernel_3375498/3654747556.py:5: RuntimeWarning: invalid value encountered in log10
#   ax.flat[i].imshow(np.log10(sample.image))
