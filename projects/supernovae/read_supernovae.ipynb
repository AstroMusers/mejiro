# %%
from mejiro.utils import util

# %%
lens_population = util.unpickle('sn_lens_population.pkl')

# %%
sample = lens_population[0]

# %%
sample.__dict__
# Out:
# {'deflector': <slsim.Deflectors.deflector.Deflector at 0x7f533889c1a0>,
#  'multi_plane': None,
#  'shear': True,
#  'convergence': True,
#  '_source': [<slsim.Sources.source.Source at 0x7f533889c440>],
#  'source_number': 1,
#  'max_redshift_source_class': <slsim.Sources.source.Source at 0x7f533889c440>,
#  '_max_redshift_source_index': 0,
#  'los_class': <slsim.LOS.los_individual.LOSIndividual at 0x7f533889c980>,
#  'cosmo': FlatLambdaCDM(name=None, H0=<Quantity 70. km / (Mpc s)>, Om0=0.3, Tcmb0=<Quantity 0. K>, Neff=3.04, m_nu=None, Ob0=0.0),
#  '_lens_equation_solver': 'lenstronomy_analytical',
#  '_magnification_limit': 0.01,
#  '_lens_cosmo': <lenstronomy.Cosmo.lens_cosmo.LensCosmo at 0x7f533889cad0>,
#  '_use_jax': True,
#  '_field_galaxies': None,
#  '_theta_E_list': [np.float64(0.8914220482398462)],
#  '_kwargs_lens': [{'theta_E': np.float64(0.892465723261395),
#    'center_x': np.float64(0.008782812949848251),
#    'center_y': np.float64(-0.05116053688472598),
# ...

# %%
sample._source[0].__dict__
# Out:
# {'extended_source_type': 'single_sersic',
#  'source_type': 'point_plus_extended',
#  '_source': <slsim.Sources.SourceTypes.point_plus_extended_source.PointPlusExtendedSource at 0x7f533889c590>}

# %%
sample._source[0]._source.__dict__
# Out:
# {'_point_source': <slsim.Sources.SourceTypes.supernova_event.SupernovaEvent at 0x7f533889c6e0>,
#  '_extended_source': <slsim.Sources.SourceTypes.single_sersic.SingleSersic at 0x7f533889c830>}

# %%
sample._source[0]._source._point_source.__dict__
# Out:
# {'name': 'SNIa',
#  '_z': 3.1969132235705224,
#  'lensed': True,
#  '_model_type': 'SourceBase',
#  '_point_source': True,
#  '_extended_source': False,
#  '_center_source': array([ 0.53955716, -0.6377376 ]),
#  '_offset': array([0, 0]),
#  'source_dict': {'M': np.float64(-21.243469399418938),
#   'coeff': array([3.84917220e-02, 2.30720263e-04, 5.18973360e-03, 9.41444471e-01,
#          1.46433536e-02]),
#   'ellipticity': np.float64(0.41914168902913107),
#   'physical_size': np.float64(2.1402336578288894),
#   'stellar_mass': np.float64(132382232215.15546),
#   'mag_F062': np.float64(25.881910500922192),
#   'mag_F087': np.float64(25.748881789211854),
#   'mag_F106': np.float64(25.707487559583566),
#   'mag_F129': np.float64(25.463906179814348),
#   'mag_F158': np.float64(25.00333225458927),
#   'mag_F184': np.float64(24.434530665862088),
#   'mag_F146': np.float64(25.09954696174049),
#   'mag_F213': np.float64(24.075385882818484),
#   'x_off': np.float64(0.040645756209791335),
# ...

# %%
sample._source[0]._source._extended_source.__dict__
# Out:
# {'name': 'GAL',
#  '_z': 3.1969132235705224,
#  'lensed': True,
#  '_model_type': 'SingleSersic',
#  '_point_source': False,
#  '_extended_source': True,
#  '_center_source': array([ 0.53955716, -0.6377376 ]),
#  '_offset': array([0, 0]),
#  'source_dict': {'kwargs_variability': {'F106',
#    'F129',
#    'F158',
#    'supernovae_lightcurve'},
#   'sn_type': 'Ia',
#   'sn_absolute_mag_band': 'bessellb',
#   'sn_absolute_zpsys': 'ab',
#   'lightcurve_time': array([-50.        , -48.99328859, -47.98657718, -46.97986577,
#          -45.97315436, -44.96644295, -43.95973154, -42.95302013,
#          -41.94630872, -40.93959732, -39.93288591, -38.9261745 ,
#          -37.91946309, -36.91275168, -35.90604027, -34.89932886,
#          -33.89261745, -32.88590604, -31.87919463, -30.87248322,
#          -29.86577181, -28.8590604 , -27.85234899, -26.84563758,
#          -25.83892617, -24.83221477, -23.82550336, -22.81879195,
#          -21.81208054, -20.80536913, -19.79865772, -18.79194631,
# ...
