# %%
import matplotlib
import numpy as np
import os
import sys
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import colors
from hydra import initialize, compose
import pickle
from glob import glob
from pprint import pprint
from tqdm import tqdm
from pyHalo.preset_models import CDM
from pyHalo import plotting_routines
from copy import deepcopy
from lenstronomy.Util.correlation import power_spectrum_1d
from lenstronomy.LensModel.Solver.lens_equation_solver import LensEquationSolver
from galsim import InterpolatedImage, Image

# set paths to various directories based on the machine this code is being executed on
with initialize(version_base=None, config_path='config'):  # ../../
    config = compose(config_name='config.yaml')  # overrides=['machine=uzay']

array_dir, data_dir, figure_dir, pickle_dir, repo_dir = config.machine.array_dir, config.machine.data_dir, config.machine.figure_dir, config.machine.pickle_dir, config.machine.repo_dir

# enable use of local modules
if repo_dir not in sys.path:
    sys.path.append(repo_dir)

# set matplotlib style
plt.style.use(f'{repo_dir}/mejiro/mplstyle/science.mplstyle')

import mejiro
from mejiro.lenses.test import SampleStrongLens
from mejiro.lenses import lens_util
from mejiro.plots import diagnostic_plot, plot, plot_util, overplot
from mejiro.analysis import ft
from mejiro.utils import util
from mejiro.helpers import gs, survey_sim, psf

# %%
ps_dir = os.path.join(data_dir, 'output', 'power_spectra_parallelized')
r = np.load(os.path.join(ps_dir, 'r.npy'))

# %%
wdm_realizations = util.unpickle_all(ps_dir, 'wdm_realization_', '.pkl')
mdm_realizations = util.unpickle_all(ps_dir, 'mdm_realization_', '.pkl')
cdm_realizations = util.unpickle_all(ps_dir, 'cdm_realization_', '.pkl')

# get average number of subhalos
num_subhalos = []
for realization in cdm_realizations:
    num_subhalos.append(len(realization.halos))
avg = np.mean(num_subhalos)
print(f'Average number of subhalos: {round(avg)}')
print(f'Square root: {round(np.sqrt(avg))}')

cdm_list = []
for realization in cdm_realizations:
    cdm_halo_masses = [halo.mass for halo in realization.halos]
    N, m = np.histogram(cdm_halo_masses, bins=np.logspace(6, 12, 20))
    cdm_list.append(N)
    plt.loglog(m[:-1], N, alpha=0.05, color='grey')

print(m[:-1])
print(np.logspace(6, 12, 19))

m_mean = np.mean(cdm_list, axis=0)
print(m_mean.shape)

m_stdev = np.std(cdm_list, axis=0)
print(m_stdev.shape)

plt.loglog(m[:-1], m_mean)
plt.fill_between(m[:-1], m_mean - m_stdev, m_mean + m_stdev, alpha=0.2)
plt.show()
# Out:
# Average number of subhalos: 5671
# Square root: 75
# [1.00000000e+06 2.06913808e+06 4.28133240e+06 8.85866790e+06
#  1.83298071e+07 3.79269019e+07 7.84759970e+07 1.62377674e+08
#  3.35981829e+08 6.95192796e+08 1.43844989e+09 2.97635144e+09
#  6.15848211e+09 1.27427499e+10 2.63665090e+10 5.45559478e+10
#  1.12883789e+11 2.33572147e+11 4.83293024e+11]
# [1.00000000e+06 2.15443469e+06 4.64158883e+06 1.00000000e+07
#  2.15443469e+07 4.64158883e+07 1.00000000e+08 2.15443469e+08
#  4.64158883e+08 1.00000000e+09 2.15443469e+09 4.64158883e+09
#  1.00000000e+10 2.15443469e+10 4.64158883e+10 1.00000000e+11
#  2.15443469e+11 4.64158883e+11 1.00000000e+12]
# (19,)
# (19,)

# %%
pprint(sorted(glob(os.path.join(ps_dir, f'res_ps_mdm_*.npy'))))
# Out:
# ['/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000153_run000.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000153_run074.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000518_run001.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000518_run075.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000545_run002.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000545_run076.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000592_run003.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000592_run077.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000605_run004.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000605_run078.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000736_run005.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000736_run079.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000778_run006.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000778_run080.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000807_run007.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000807_run081.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000906_run008.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000906_run082.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000987_run009.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00000987_run083.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001103_run010.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001103_run084.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001420_run011.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001420_run085.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001622_run012.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001622_run086.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001658_run013.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00001658_run087.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002110_run014.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002110_run088.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002123_run015.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002123_run089.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002164_run016.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002164_run090.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002288_run017.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002288_run091.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002294_run018.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002294_run092.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002300_run019.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002300_run093.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002351_run020.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002351_run094.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002501_run021.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002501_run095.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002520_run022.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002520_run096.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002557_run023.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002557_run097.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002591_run024.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002591_run098.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002605_run025.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002605_run099.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002840_run026.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002868_run027.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002871_run028.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002889_run029.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00002893_run030.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003103_run031.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003124_run032.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003282_run033.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003321_run034.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003360_run035.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003605_run036.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003776_run037.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003859_run038.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00003976_run039.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00004221_run040.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00004713_run041.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00004914_run042.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00004930_run043.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00005147_run044.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00005292_run045.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00005680_run046.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00005849_run047.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006021_run048.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006177_run049.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006196_run050.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006275_run051.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006282_run052.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006336_run053.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006427_run054.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006542_run055.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006689_run056.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006880_run057.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006988_run058.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00006993_run059.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00007009_run060.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00007045_run061.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00007143_run062.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00007732_run063.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00008051_run064.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00008345_run065.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00008429_run066.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00008554_run067.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00009024_run068.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00009090_run069.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00009117_run070.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00009474_run071.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00009716_run072.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_mdm_00009949_run073.npy']

# %%
res_wdm_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_wdm_*.npy'))]
res_mdm_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_mdm_*.npy'))]

mean_wdm = np.mean(res_wdm_list, axis=0)
mean_mdm = np.mean(res_mdm_list, axis=0)

# TODO make percentile instead of std because doesn't reflect asymmetry of distribution? but unclear what percentile would mean in this context
std_wdm = np.std(res_wdm_list, axis=0, ddof=1)
std_mdm = np.std(res_mdm_list, axis=0, ddof=1)

# %%
plt.plot(r, mean_wdm, label='WDM', color='C3', lw=4)
plt.fill_between(r, mean_wdm - std_wdm, mean_wdm + std_wdm, alpha=0.2, color='C3')
plt.plot(r, mean_mdm, label='MDM', color='C4', lw=4)
plt.fill_between(r, mean_mdm - std_mdm, mean_mdm + std_mdm, alpha=0.2, color='C4')
plt.axhline(0, color='black')

for _, res in enumerate(res_wdm_list):
    plt.plot(r, res, color='C3', alpha=0.2)

for _, res in enumerate(res_mdm_list):
    plt.plot(r, res, color='C4', alpha=0.2)

plt.xscale('log')
plt.legend()
plt.title('Difference in power spectra of images\nVaried subhalo populations wrt all CDM subhalos')
plt.show()

# %%
pprint(sorted(glob(os.path.join(ps_dir, f'res_ps_pos_1_*.npy'))))
# Out:
# ['/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000153_run000.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000153_run074.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000518_run001.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000518_run075.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000545_run002.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000545_run076.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000592_run003.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000592_run077.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000605_run004.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000605_run078.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000736_run005.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000736_run079.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000778_run006.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000778_run080.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000807_run007.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000807_run081.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000906_run008.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000906_run082.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000987_run009.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00000987_run083.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001103_run010.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001103_run084.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001420_run011.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001420_run085.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001622_run012.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001622_run086.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001658_run013.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00001658_run087.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002110_run014.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002110_run088.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002123_run015.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002123_run089.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002164_run016.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002164_run090.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002288_run017.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002288_run091.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002294_run018.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002294_run092.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002300_run019.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002300_run093.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002351_run020.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002351_run094.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002501_run021.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002501_run095.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002520_run022.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002520_run096.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002557_run023.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002557_run097.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002591_run024.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002591_run098.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002605_run025.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002605_run099.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002840_run026.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002868_run027.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002871_run028.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002889_run029.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00002893_run030.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003103_run031.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003124_run032.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003282_run033.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003321_run034.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003360_run035.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003605_run036.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003776_run037.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003859_run038.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00003976_run039.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00004221_run040.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00004713_run041.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00004914_run042.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00004930_run043.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00005147_run044.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00005292_run045.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00005680_run046.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00005849_run047.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006021_run048.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006177_run049.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006196_run050.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006275_run051.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006282_run052.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006336_run053.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006427_run054.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006542_run055.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006689_run056.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006880_run057.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006988_run058.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00006993_run059.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00007009_run060.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00007045_run061.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00007143_run062.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00007732_run063.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00008051_run064.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00008345_run065.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00008429_run066.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00008554_run067.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00009024_run068.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00009090_run069.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00009117_run070.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00009474_run071.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00009716_run072.npy',
#  '/data/bwedig/mejiro/output/power_spectra_parallelized/res_ps_pos_1_00009949_run073.npy']

# %%
res_pos_1_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_1_*.npy'))]
res_pos_2_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_2_*.npy'))]
res_pos_3_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_3_*.npy'))]
res_pos_4_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_4_*.npy'))]
res_pos_5_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_5_*.npy'))]
res_pos_6_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_6_*.npy'))]
res_pos_7_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_7_*.npy'))]
res_pos_8_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_8_*.npy'))]
res_pos_9_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_9_*.npy'))]
res_pos_10_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_10_*.npy'))]
res_pos_11_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_11_*.npy'))]
res_pos_12_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_12_*.npy'))]
res_pos_13_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_13_*.npy'))]
res_pos_14_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_14_*.npy'))]
res_pos_15_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_15_*.npy'))]
res_pos_16_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_16_*.npy'))]
res_pos_17_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_17_*.npy'))]
res_pos_18_list = [np.load(i) for i in glob(os.path.join(ps_dir, f'res_ps_pos_18_*.npy'))]

mean_pos_1 = np.mean(res_pos_1_list, axis=0)
mean_pos_2 = np.mean(res_pos_2_list, axis=0)
mean_pos_3 = np.mean(res_pos_3_list, axis=0)
mean_pos_4 = np.mean(res_pos_4_list, axis=0)
mean_pos_5 = np.mean(res_pos_5_list, axis=0)
mean_pos_6 = np.mean(res_pos_6_list, axis=0)
mean_pos_7 = np.mean(res_pos_7_list, axis=0)
mean_pos_8 = np.mean(res_pos_8_list, axis=0)
mean_pos_9 = np.mean(res_pos_9_list, axis=0)
mean_pos_10 = np.mean(res_pos_10_list, axis=0)
mean_pos_11 = np.mean(res_pos_11_list, axis=0)
mean_pos_12 = np.mean(res_pos_12_list, axis=0)
mean_pos_13 = np.mean(res_pos_13_list, axis=0)
mean_pos_14 = np.mean(res_pos_14_list, axis=0)
mean_pos_15 = np.mean(res_pos_15_list, axis=0)
mean_pos_16 = np.mean(res_pos_16_list, axis=0)
mean_pos_17 = np.mean(res_pos_17_list, axis=0)
mean_pos_18 = np.mean(res_pos_18_list, axis=0)

std_pos_1 = np.std(res_pos_1_list, axis=0, ddof=1)
std_pos_2 = np.std(res_pos_2_list, axis=0, ddof=1)
std_pos_3 = np.std(res_pos_3_list, axis=0, ddof=1)
# std_pos_4 = np.std(res_pos_4_list, axis=0, ddof=1)
# std_pos_5 = np.std(res_pos_5_list, axis=0, ddof=1)
# std_pos_6 = np.std(res_pos_6_list, axis=0, ddof=1)
# std_pos_7 = np.std(res_pos_7_list, axis=0, ddof=1)
# std_pos_8 = np.std(res_pos_8_list, axis=0, ddof=1)
# std_pos_9 = np.std(res_pos_9_list, axis=0, ddof=1)
# std_pos_10 = np.std(res_pos_10_list, axis=0, ddof=1)
# std_pos_11 = np.std(res_pos_11_list, axis=0, ddof=1)
# std_pos_12 = np.std(res_pos_12_list, axis=0, ddof=1)
# std_pos_13 = np.std(res_pos_13_list, axis=0, ddof=1)
# std_pos_14 = np.std(res_pos_14_list, axis=0, ddof=1)
# std_pos_15 = np.std(res_pos_15_list, axis=0, ddof=1)
# std_pos_16 = np.std(res_pos_16_list, axis=0, ddof=1)
# std_pos_17 = np.std(res_pos_17_list, axis=0, ddof=1)
# std_pos_18 = np.std(res_pos_18_list, axis=0, ddof=1)

# %%
plt.plot(r, mean_pos_1, label='Position 1', color='C0', lw=4)
plt.fill_between(r, mean_pos_1 - std_pos_1, mean_pos_1 + std_pos_1, alpha=0.2, color='C0')
plt.plot(r, mean_pos_2, label='Position 2', color='C1', lw=4)
plt.fill_between(r, mean_pos_2 - std_pos_2, mean_pos_2 + std_pos_2, alpha=0.2, color='C1')
plt.plot(r, mean_pos_3, label='Position 3', color='C2', lw=4)
plt.fill_between(r, mean_pos_3 - std_pos_3, mean_pos_3 + std_pos_3, alpha=0.2, color='C2')
plt.axhline(0, color='black')

for _, res in enumerate(res_pos_1_list):
    plt.plot(r, res, color='C0', alpha=0.2)

for _, res in enumerate(res_pos_2_list):
    plt.plot(r, res, color='C1', alpha=0.2)

for _, res in enumerate(res_pos_3_list):
    plt.plot(r, res, color='C2', alpha=0.2)

plt.xscale('log')
plt.legend()
plt.title('')
plt.show()

# %%
plt.plot(r, mean_pos_1, label='SCA01', color='C0')
plt.plot(r, mean_pos_2, label='SCA02', color='C1')  #
plt.plot(r, mean_pos_3, label='SCA03', color='C2')
plt.plot(r, mean_pos_4, label='SCA04', color='C3')
plt.plot(r, mean_pos_5, label='SCA05', color='C4')  #
plt.plot(r, mean_pos_6, label='SCA06', color='C5')
plt.plot(r, mean_pos_7, label='SCA07', color='C6')
plt.plot(r, mean_pos_8, label='SCA08', color='C7')
plt.plot(r, mean_pos_9, label='SCA09', color='C8')
plt.plot(r, mean_pos_10, label='SCA10', color='C9')
plt.plot(r, mean_pos_11, label='SCA11', color='C0')  #
plt.plot(r, mean_pos_12, label='SCA12', color='C1')
plt.plot(r, mean_pos_13, label='SCA13', color='C2')  #
plt.plot(r, mean_pos_14, label='SCA14', color='C3')  #
plt.plot(r, mean_pos_15, label='SCA15', color='C4')
plt.plot(r, mean_pos_16, label='SCA16', color='C5')
plt.plot(r, mean_pos_17, label='SCA17', color='C6')
plt.plot(r, mean_pos_18, label='SCA18', color='C7')
plt.plot(r, mean_wdm, label='WDM', color='black', lw=4, linestyle=':')
plt.plot(r, mean_mdm, label='MDM', color='black', lw=4)
# plt.axhline(0, color='black')

plt.xscale('log')
plt.legend(loc=4)
plt.title('')
plt.show()
