# %%
import numpy as np
from mejiro.engines.stpsf_engine import STPSFEngine

# %%
jwst_psf = STPSFEngine.get_jwst_psf('F115W', 1, 41)
# Out:
# Generating PSF with STPSF, which may be slow. Consider caching frequently-used PSFs.

# %%
import matplotlib.pyplot as plt

plt.imshow(np.log10(jwst_psf), cmap='inferno')
plt.colorbar()
plt.show()

# %%
np.save('psf_jwst_f115w.npy', jwst_psf)
