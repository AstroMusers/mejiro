# %%
import numpy as np
import os
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import colors
import pickle
from glob import glob
from pprint import pprint

# set matplotlib style
# plt.style.use(f'{repo_dir}/mejiro/mplstyle/science.mplstyle')

from mejiro.utils import util
from mejiro.instruments.roman import Roman
from mejiro.synthetic_image import SyntheticImage
from mejiro.exposure import Exposure
from mejiro.galaxy_galaxy import SampleBELLS, SampleSL2S, SampleGG

# %%
strong_lens = SampleGG()

synthetic_image = SyntheticImage(strong_lens=strong_lens,
                                instrument=Roman(),
                                band='F129',
                                verbose=False)

# %%
exposure = Exposure(synthetic_image,
                    exposure_time=188.48,
                    engine='romanisim',
                    verbose=True)

exposure.plot()
# Out:
# 2025-06-06 11:43:07 INFO     Apportioning electrons to resultants...
# 2025-06-06 11:43:07 WARNING  No RNG set, constructing a new default RNG from default seed.
# 2025-06-06 11:43:10 INFO     Adding IPC...
# 2025-06-06 11:43:10 INFO     Adding read noise...
# 2025-06-06 11:43:10 WARNING  No RNG set, constructing a new default RNG from default seed.
# 2025-06-06 11:43:10 INFO     Fitting ramps.
# /grad/bwedig/mejiro/mejiro/exposure.py:118: UserWarning: Negative pixel values in final image. Setting 1578 pixels to 0
#   warnings.warn(f'Negative pixel values in final image. Setting {np.sum(self.exposure < 0)} pixels to 0')
# /grad/bwedig/mejiro/mejiro/exposure.py:136: RuntimeWarning: invalid value encountered in log10
#   plt.imshow(np.log10(self.exposure))
# Exposure calculation time with romanisim engine: 4.54 s
